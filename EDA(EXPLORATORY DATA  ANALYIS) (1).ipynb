# %% [markdown]
# # Superstore Dataset: Data Analysis Report
#
# Introduction:
#
# The Superstore dataset is a comprehensive retail dataset that captures sales transactions, containing information about orders, customers, products, and shipping details across different regions. It provides valuable insights into various business aspects including sales performance, shipping preferences, and customer segmentation, making it an excellent resource for analyzing retail operations and understanding business patterns from 2014 to 2017.
#
# # Data Overview:
#
# * The dataset includes the following columns:
#
#
#   Order Details: Order_ID,Order_Date,_Ship Date.
#
#
#   Customer Information: Cutomer_ID,Customer_Name.
#
#
#   Product Details: Product_ID,Product_Name
#
#
#   Segmentation: Segment,Category,sub-Category
#
#
#   Geographical Information: Region,Country,City,State
#
#
#   Financial Metrics:Sales,Quantity,Discount,Profit
#
#
#
# # Data Visualization:
#
# 1.Ship Mode Analysis:
# * pie chart showing distribution of shipping modes.
# * count plot of ship mode using seaborn(with winter palette).
# * count plot showing relationship between ship mode category.
#
# 2.Category Analysis:
# * count plot showing distribution of product categories.
# * count plot showing relationship between categories and sub_categories.
# * seperate count plots for each main category(Furniture,Technology,Office Supplies)showing their sub-categories.
#
# 3.Segment Analysis:
# * Count Plot showing distribution of customer segments.
#
# 4.Order Year Analysis:
# * Count plot showing distribution of orders across years(2014-2017)
# * value counts showing:
#
#   2017:3,312 orders
#
#   2016:2,587 orders
#
#   2015:2,102 orders
#
#   2014:1,993 orders
#
#
# # Visualization Techniques Used:
# 1. Seaborn's Countplot() for categorical data analysis.
# 2. Matplotlib's pie() for percentage distribution.
# 3. Color schemes:
# * winter palette for some visualizations
# * default color schemes for others
# 4. proper titles and labels for better understanding
# 5. Legend usage where multiple categories are shown
#
# These Visualizations help in understanding the distribution and relationships between different variables in the superstore dataset,making it easier to identify patterns and trends in the data.
#
# # Insights:
# The Superstore dataset reveals standard class as the most popular shipping mode,indicating customer preference for economical options.Office supplies is the top  selling category,with diverse sub categories across all product lines.There's a clear upward trend in order volumne from 2014-2017,suggesting consistent business growth and expanding customer base across different segments and regions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# SET THE THEME FOR THE PLOTS
plt.style.use('dark_background')

# %%
dataset=pd.read_excel("Sample - Superstore1.xlsx")

# %%
dataset.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
dataset.tail(2)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID Customer Name   Segment        Country         City  ...  \
# 9992    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.60         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.16         2
#
#       Discount  Profit
# 9992       0.0  13.320
# 9993       0.0  72.948
#
# ...

# %%
dataset.shape
# Out:
# (9994, 21)

# %%
dataset.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
dataset.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
print(dataset['Category'].unique())
print
# Out:
# ['Furniture' 'Office Supplies' 'Technology']
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print(dataset['State'].unique())
print
# Out:
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
dataset['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
dataset.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %% [markdown]
# # SHIP MODE

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
x=dataset['Ship Mode'].value_counts().index
y=dataset['Ship Mode'].value_counts().values

# %%
plt.pie(y,labels=x,startangle=60,autopct="%0.2f%%")
plt.legend(loc=2)
plt.show()

# %%
sns.countplot(x="Ship Mode",
              data=dataset,
              palette="winter")
plt.title("Count Of Ship Mode")
plt.show()

# %% [markdown]
# #  CATEGORY

# %%
sns.countplot(x="Ship Mode",data=dataset,hue="Category")
plt.title("CATEGORY")
plt.savefig("CATEGORY.jpg")
plt.show()

# %% [markdown]
# # SEGMENT

# %%
sns.countplot(x="Segment",data=dataset)
plt.title("Segment")
plt.show()

# %% [markdown]
# # SUB CATEGORY

# %%
sns.countplot(x="Category",
              data=dataset[dataset["Category"]=="Office Supplies"],
              hue="Sub-Category")
plt.title("SUB CATEGORY")
plt.show()

# %%
sns.countplot(x="Category",
              data=dataset[dataset["Category"]=="Technology"],
              hue="Sub-Category")
plt.title("SUB CATEGORY")
plt.show()

# %%
sns.countplot(x="Category",
              data=dataset[dataset["Category"]=="Furniture"],
              hue="Sub-Category")
plt.title("SUB CATEGORY")
plt.show()

# %% [markdown]
# # ORDER YEAR

# %%
 dataset["order year"]= dataset["Order Date"].dt.year

# %%
dataset["order year"].value_counts()
# Out:
# order year
# 2017    3312
# 2016    2587
# 2015    2102
# 2014    1993
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
dataset['Order Date'] = pd.to_datetime(dataset['Order Date'])
dataset.set_index('Order Date', inplace=True)

monthly_sales = dataset['Sales'].resample('M').sum()

plt.figure(figsize=(14, 7))
monthly_sales.plot()
plt.title('Monthly Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # DISCOUNT

# %%
plt.figure(figsize=(10, 6))
sns.histplot(dataset['Discount'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Discounts')
plt.xlabel('Discount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # PROFIT

# %%
sns.barplot(x="Category",y="Profit",data=dataset,estimator="sum")
plt.show()

# %% [markdown]
# # CITY

# %%
dataset['City'].value_counts()[:5]
# Out:
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
numeric_data = dataset.select_dtypes(include=['float64', 'int64'])
corr = numeric_data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # CONCLUSION:-
#
# The SuperStore dataset provides valuable insights into sales performance, profitability, and customer purchasing behavior.
# These insights can guide strategic decisions in inventory management, marketing, and sales optimization to enhance overall business performance.
